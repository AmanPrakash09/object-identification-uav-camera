# %% [markdown]
# # EfficientDet COCO Benchmark
#
# ### Setup Dependencies

# %%
# Setup Dependencies (EfficientDet)

import os
import time
import torch
import numpy as np
import psutil
import cv2
import matplotlib.pyplot as plt

from effdet import create_model, DetBenchPredict
from effdet.data import resolve_input_config

print("-" * 50)
print(f"PyTorch version: {torch.__version__}")
print(f"GPU Available: {torch.cuda.is_available()}")
print(f"CPU Cores: {psutil.cpu_count(logical=True)}")
print("-" * 50)
# Out:
# --------------------------------------------------
# PyTorch version: 2.9.1
# GPU Available: False
# CPU Cores: 8
# --------------------------------------------------

# %% [markdown]
# ### Configure Local COCO Paths

# %%
COCO_ROOT = os.path.abspath(
    os.path.join(os.getcwd(), "..", "coco-dataset", "coco-2017")
)

VAL_IMAGES = os.path.join(COCO_ROOT, "validation", "data")
VAL_ANN    = os.path.join(COCO_ROOT, "validation", "labels.json")

print("Images path:     ", VAL_IMAGES)
print("Annotation file: ", VAL_ANN)
print("Images found:    ", len(os.listdir(VAL_IMAGES)))

image_files = os.listdir(VAL_IMAGES)
print("Number of validation images:", len(image_files))
# Out:
# Images path:      /Users/g/Documents/CPEN491/object-identification-uav-camera/phase-1/coco-dataset/coco-2017/validation/data
# Annotation file:  /Users/g/Documents/CPEN491/object-identification-uav-camera/phase-1/coco-dataset/coco-2017/validation/labels.json
# Images found:     3125
# Number of validation images: 3125

# %% [markdown]
# ## Load EfficientDet Model

# %%
# Create EfficientDet model (fixed for current effdet version)

from effdet import create_model  # DetBenchPredict not needed here

MODEL_NAME = "efficientdet_d0"   # small & fast variant
NUM_CLASSES = 91                 # COCO-style config

model = create_model(
    MODEL_NAME,
    bench_task="predict",        # returns a prediction bench model
    pretrained=True,             # load pretrained COCO weights
    num_classes=NUM_CLASSES,
)

model.eval()

num_params = sum(p.numel() for p in model.parameters())
print(f"Created model: {MODEL_NAME}")
print(f"Number of parameters: {num_params:,}")
# Out:
# Created model: efficientdet_d0
# Number of parameters: 3,878,348

# %%
INPUT_H = 512
INPUT_W = 512
print("Using EfficientDet-D0 input size:", INPUT_H, INPUT_W)
# Out:
# Using EfficientDet-D0 input size: 512 512

# %%
import json
import numpy as np
from pycocotools.coco import COCO

# ---- Load GT and your predictions ----
coco_gt = COCO(VAL_ANN)

with open("efficientdet_results.json", "r") as f:
    preds = json.load(f)

print("Total predictions loaded:", len(preds))
print("="*60)

# ---- Build helper maps ----
gt_image_ids = set(coco_gt.getImgIds())
gt_category_ids = set(coco_gt.getCatIds())

# ---- Utility: compute IoU ----
def compute_iou(box1, box2):
    # box = [x1, y1, w, h]
    x1, y1, w1, h1 = box1
    x2, y2, w2, h2 = box2

    xa = max(x1, x2)
    ya = max(y1, y2)
    xb = min(x1 + w1, x2 + w2)
    yb = min(y1 + h1, y2 + h2)

    inter = max(0, xb - xa) * max(0, yb - ya)
    union = w1*h1 + w2*h2 - inter

    if union == 0:
        return 0

    return inter / union

# ---- SANITY CHECK LOOP ----
max_checks = 50  # don't print everything, just first 50 predictions
problems_found = False

for i, p in enumerate(preds[:max_checks]):
    img_id    = p["image_id"]
    cat_id    = p["category_id"]
    x, y, w, h = p["bbox"]

    print(f"\nPrediction #{i+1}")
    print(p)

    # 1. IMAGE ID CHECK
    if img_id not in gt_image_ids:
        print("❌ ERROR: image_id not in ground-truth annotations!")
        problems_found = True
        continue
    else:
        print("✔ image_id exists")

    # 2. CATEGORY ID CHECK
    if cat_id not in gt_category_ids:
        print("❌ ERROR: category_id invalid for this COCO dataset!")
        problems_found = True
        continue
    else:
        print("✔ category_id valid")

    # 3. BBOX CHECK
    if w <= 0 or h <= 0:
        print("❌ ERROR: invalid width/height!")
        problems_found = True
        continue
    else:
        print("✔ bbox format OK")

    # 4. IOU CHECK — must overlap at least ONE GT box
    ann_ids = coco_gt.getAnnIds(imgIds=[img_id])
    anns = coco_gt.loadAnns(ann_ids)

    max_iou = 0
    for ann in anns:
        gt_box = ann["bbox"]  # [x,y,w,h]
        iou = compute_iou(p["bbox"], gt_box)
        max_iou = max(max_iou, iou)

    if max_iou < 0.01:
        print(f"❌ WARNING: No overlap with any GT box (max IoU={max_iou:.3f})")
        # Not always an error — model might simply be wrong — but check next predictions
    else:
        print(f"✔ Overlaps GT (max IoU={max_iou:.3f})")

    print("-"*60)

if not problems_found:
    print("\n🎉 Sanity check passed for the first 50 predictions!")
else:
    print("\n⚠ Some issues found above — fix them before running COCOeval.")
# Out:
# loading annotations into memory...
# Done (t=0.15s)
# creating index...
# index created!
# Total predictions loaded: 698
# ============================================================
#
# Prediction #1
# {'image_id': 301563, 'category_id': 75, 'bbox': [65.8560791015625, 103.18494415283203, 64.62586975097656, 25.98821258544922], 'score': 0.05012336000800133}
# ✔ image_id exists
# ✔ category_id valid
# ✔ bbox format OK
# ✔ Overlaps GT (max IoU=0.138)
# ------------------------------------------------------------
#
# Prediction #2
# {'image_id': 459195, 'category_id': 24, 'bbox': [323.4713439941406, 192.60752868652344, 31.62396240234375, 28.888290405273438], 'score': 0.05605347454547882}
# ✔ image_id exists
# ✔ category_id valid
# ✔ bbox format OK
# ✔ Overlaps GT (max IoU=0.593)
# ------------------------------------------------------------
#
# Prediction #3
# {'image_id': 268729, 'category_id': 47, 'bbox': [252.41656494140625, 308.9820556640625, 85.76644897460938, 49.07269287109375], 'score': 0.05982031673192978}
# ✔ image_id exists
# ✔ category_id valid
# ✔ bbox format OK
# ✔ Overlaps GT (max IoU=0.231)
# ------------------------------------------------------------
#
# Prediction #4
# {'image_id': 465718, 'category_id': 62, 'bbox': [491.61639404296875, 356.6763916015625, 38.6717529296875, 47.1859130859375], 'score': 0.053100794553756714}
# ✔ image_id exists
# ✔ category_id valid
# ✔ bbox format OK
# ✔ Overlaps GT (max IoU=0.940)
# ------------------------------------------------------------
#
# Prediction #5
# {'image_id': 465718, 'category_id': 49, 'bbox': [477.34674072265625, 365.4585266113281, 65.67767333984375, 36.462646484375], 'score': 0.052823375910520554}
# ✔ image_id exists
# ✔ category_id valid
# ✔ bbox format OK
# ✔ Overlaps GT (max IoU=0.517)
# ------------------------------------------------------------
#
# Prediction #6
# {'image_id': 522889, 'category_id': 41, 'bbox': [72.86186218261719, 160.30508422851562, 63.881500244140625, 60.96649169921875], 'score': 0.06038835272192955}
# ✔ image_id exists
# ✔ category_id valid
# ✔ bbox format OK
# ✔ Overlaps GT (max IoU=0.436)
# ------------------------------------------------------------
#
# Prediction #7
# {'image_id': 522889, 'category_id': 24, 'bbox': [95.24714660644531, 185.77139282226562, 12.523628234863281, 16.6180419921875], 'score': 0.0531156100332737}
# ✔ image_id exists
# ✔ category_id valid
# ✔ bbox format OK
# ✔ Overlaps GT (max IoU=0.023)
# ------------------------------------------------------------
#
# Prediction #8
# {'image_id': 522889, 'category_id': 40, 'bbox': [101.7125015258789, 184.91049194335938, 13.781227111816406, 17.405929565429688], 'score': 0.05240500345826149}
# ✔ image_id exists
# ✔ category_id valid
# ✔ bbox format OK
# ✔ Overlaps GT (max IoU=0.027)
# ------------------------------------------------------------
#
# Prediction #9
# {'image_id': 522889, 'category_id': 77, 'bbox': [79.08717346191406, 78.29476928710938, 52.16633605957031, 45.70545959472656], 'score': 0.051845476031303406}
# ✔ image_id exists
# ✔ category_id valid
# ✔ bbox format OK
# ❌ WARNING: No overlap with any GT box (max IoU=0.000)
# ------------------------------------------------------------
#
# Prediction #10
# {'image_id': 522889, 'category_id': 42, 'bbox': [83.39306640625, 161.69190979003906, 46.8775634765625, 75.29156494140625], 'score': 0.051727160811424255}
# ✔ image_id exists
# ✔ category_id valid
# ✔ bbox format OK
# ✔ Overlaps GT (max IoU=0.395)
# ------------------------------------------------------------
#
# Prediction #11
# {'image_id': 231879, 'category_id': 15, 'bbox': [455.7569580078125, 160.3385467529297, 77.296875, 29.305511474609375], 'score': 0.1223180741071701}
# ✔ image_id exists
# ✔ category_id valid
# ✔ bbox format OK
# ✔ Overlaps GT (max IoU=0.210)
# ------------------------------------------------------------
#
# Prediction #12
# {'image_id': 231879, 'category_id': 80, 'bbox': [477.168212890625, 152.92721557617188, 58.44122314453125, 52.61109924316406], 'score': 0.09459500759840012}
# ✔ image_id exists
# ✔ category_id valid
# ✔ bbox format OK
# ✔ Overlaps GT (max IoU=0.269)
# ------------------------------------------------------------
#
# Prediction #13
# {'image_id': 231879, 'category_id': 17, 'bbox': [470.0650634765625, 155.47683715820312, 62.1033935546875, 49.589508056640625], 'score': 0.09230407327413559}
# ✔ image_id exists
# ✔ category_id valid
# ✔ bbox format OK
# ✔ Overlaps GT (max IoU=0.272)
# ------------------------------------------------------------
#
# Prediction #14
# {'image_id': 231879, 'category_id': 57, 'bbox': [465.7069091796875, 159.9478759765625, 70.52520751953125, 29.669143676757812], 'score': 0.09029002487659454}
# ✔ image_id exists
# ✔ category_id valid
# ✔ bbox format OK
# ✔ Overlaps GT (max IoU=0.194)
# ------------------------------------------------------------
#
# Prediction #15
# {'image_id': 231879, 'category_id': 65, 'bbox': [477.168212890625, 152.92721557617188, 58.44122314453125, 52.61109924316406], 'score': 0.08095304667949677}
# ✔ image_id exists
# ✔ category_id valid
# ✔ bbox format OK
# ✔ Overlaps GT (max IoU=0.269)
# ------------------------------------------------------------
#
# Prediction #16
# {'image_id': 231879, 'category_id': 81, 'bbox': [473.68597412109375, 157.55189514160156, 61.02728271484375, 38.15019226074219], 'score': 0.07813011854887009}
# ✔ image_id exists
# ✔ category_id valid
# ✔ bbox format OK
# ✔ Overlaps GT (max IoU=0.216)
# ------------------------------------------------------------
#
# Prediction #17
# {'image_id': 231879, 'category_id': 16, 'bbox': [455.7569580078125, 160.3385467529297, 77.296875, 29.305511474609375], 'score': 0.07645244896411896}
# ✔ image_id exists
# ✔ category_id valid
# ✔ bbox format OK
# ✔ Overlaps GT (max IoU=0.210)
# ------------------------------------------------------------
#
# Prediction #18
# {'image_id': 231879, 'category_id': 55, 'bbox': [482.2261047363281, 159.08026123046875, 40.833221435546875, 34.80284118652344], 'score': 0.07422258704900742}
# ✔ image_id exists
# ✔ category_id valid
# ✔ bbox format OK
# ✔ Overlaps GT (max IoU=0.132)
# ------------------------------------------------------------
#
# Prediction #19
# {'image_id': 231879, 'category_id': 52, 'bbox': [455.7569580078125, 160.3385467529297, 77.296875, 29.305511474609375], 'score': 0.07328131049871445}
# ✔ image_id exists
# ✔ category_id valid
# ✔ bbox format OK
# ✔ Overlaps GT (max IoU=0.210)
# ------------------------------------------------------------
#
# Prediction #20
# {'image_id': 231879, 'category_id': 15, 'bbox': [480.83099365234375, 155.9347686767578, 60.24261474609375, 28.569931030273438], 'score': 0.06714850664138794}
# ✔ image_id exists
# ✔ category_id valid
# ✔ bbox format OK
# ✔ Overlaps GT (max IoU=0.153)
# ------------------------------------------------------------
#
# Prediction #21
# {'image_id': 231879, 'category_id': 65, 'bbox': [490.7176208496094, 157.3112335205078, 38.993377685546875, 38.04374694824219], 'score': 0.06639176607131958}
# ✔ image_id exists
# ✔ category_id valid
# ✔ bbox format OK
# ✔ Overlaps GT (max IoU=0.138)
# ------------------------------------------------------------
#
# Prediction #22
# {'image_id': 231879, 'category_id': 64, 'bbox': [484.3680114746094, 155.06918334960938, 48.382965087890625, 44.40606689453125], 'score': 0.06297722458839417}
# ✔ image_id exists
# ✔ category_id valid
# ✔ bbox format OK
# ✔ Overlaps GT (max IoU=0.199)
# ------------------------------------------------------------
#
# Prediction #23
# {'image_id': 231879, 'category_id': 87, 'bbox': [480.7577209472656, 162.48178100585938, 54.943939208984375, 23.631027221679688], 'score': 0.06165159493684769}
# ✔ image_id exists
# ✔ category_id valid
# ✔ bbox format OK
# ✔ Overlaps GT (max IoU=0.120)
# ------------------------------------------------------------
#
# Prediction #24
# {'image_id': 231879, 'category_id': 51, 'bbox': [439.86962890625, 157.0077362060547, 96.34490966796875, 43.977752685546875], 'score': 0.06067407876253128}
# ✔ image_id exists
# ✔ category_id valid
# ✔ bbox format OK
# ✔ Overlaps GT (max IoU=0.393)
# ------------------------------------------------------------
#
# Prediction #25
# {'image_id': 231879, 'category_id': 86, 'bbox': [465.89178466796875, 158.1592559814453, 67.07525634765625, 36.51313781738281], 'score': 0.060403306037187576}
# ✔ image_id exists
# ✔ category_id valid
# ✔ bbox format OK
# ✔ Overlaps GT (max IoU=0.227)
# ------------------------------------------------------------
#
# Prediction #26
# {'image_id': 231879, 'category_id': 15, 'bbox': [457.0694580078125, 171.73670959472656, 83.2193603515625, 31.0238037109375], 'score': 0.06018897145986557}
# ✔ image_id exists
# ✔ category_id valid
# ✔ bbox format OK
# ✔ Overlaps GT (max IoU=0.234)
# ------------------------------------------------------------
#
# Prediction #27
# {'image_id': 231879, 'category_id': 77, 'bbox': [490.7176208496094, 157.3112335205078, 38.993377685546875, 38.04374694824219], 'score': 0.05940338596701622}
# ✔ image_id exists
# ✔ category_id valid
# ✔ bbox format OK
# ✔ Overlaps GT (max IoU=0.138)
# ------------------------------------------------------------
#
# Prediction #28
# {'image_id': 231879, 'category_id': 90, 'bbox': [455.7569580078125, 160.3385467529297, 77.296875, 29.305511474609375], 'score': 0.059118255972862244}
# ✔ image_id exists
# ✔ category_id valid
# ✔ bbox format OK
# ✔ Overlaps GT (max IoU=0.210)
# ------------------------------------------------------------
#
# Prediction #29
# {'image_id': 231879, 'category_id': 33, 'bbox': [465.7069091796875, 159.9478759765625, 70.52520751953125, 29.669143676757812], 'score': 0.05878546088933945}
# ✔ image_id exists
# ✔ category_id valid
# ✔ bbox format OK
# ✔ Overlaps GT (max IoU=0.194)
# ------------------------------------------------------------
#
# Prediction #30
# {'image_id': 231879, 'category_id': 15, 'bbox': [481.56256103515625, 168.83291625976562, 75.57781982421875, 28.846237182617188], 'score': 0.058118388056755066}
# ✔ image_id exists
# ✔ category_id valid
# ✔ bbox format OK
# ✔ Overlaps GT (max IoU=0.146)
# ------------------------------------------------------------
#
# Prediction #31
# {'image_id': 231879, 'category_id': 54, 'bbox': [444.2108154296875, 161.2146759033203, 87.6680908203125, 28.946319580078125], 'score': 0.055946849286556244}
# ✔ image_id exists
# ✔ category_id valid
# ✔ bbox format OK
# ✔ Overlaps GT (max IoU=0.235)
# ------------------------------------------------------------
#
# Prediction #32
# {'image_id': 231879, 'category_id': 20, 'bbox': [439.86962890625, 157.0077362060547, 96.34490966796875, 43.977752685546875], 'score': 0.0558115653693676}
# ✔ image_id exists
# ✔ category_id valid
# ✔ bbox format OK
# ✔ Overlaps GT (max IoU=0.393)
# ------------------------------------------------------------
#
# Prediction #33
# {'image_id': 231879, 'category_id': 55, 'bbox': [492.30810546875, 152.24290466308594, 40.0445556640625, 37.307952880859375], 'score': 0.0553361214697361}
# ✔ image_id exists
# ✔ category_id valid
# ✔ bbox format OK
# ✔ Overlaps GT (max IoU=0.139)
# ------------------------------------------------------------
#
# Prediction #34
# {'image_id': 231879, 'category_id': 47, 'bbox': [465.7069091796875, 159.9478759765625, 70.52520751953125, 29.669143676757812], 'score': 0.05512664094567299}
# ✔ image_id exists
# ✔ category_id valid
# ✔ bbox format OK
# ✔ Overlaps GT (max IoU=0.194)
# ------------------------------------------------------------
#
# Prediction #35
# {'image_id': 231879, 'category_id': 88, 'bbox': [482.2261047363281, 159.08026123046875, 40.833221435546875, 34.80284118652344], 'score': 0.054516445845365524}
# ✔ image_id exists
# ✔ category_id valid
# ✔ bbox format OK
# ✔ Overlaps GT (max IoU=0.132)
# ------------------------------------------------------------
#
# Prediction #36
# {'image_id': 231879, 'category_id': 21, 'bbox': [490.7176208496094, 157.3112335205078, 38.993377685546875, 38.04374694824219], 'score': 0.05428210645914078}
# ✔ image_id exists
# ✔ category_id valid
# ✔ bbox format OK
# ✔ Overlaps GT (max IoU=0.138)
# ------------------------------------------------------------
#
# Prediction #37
# {'image_id': 231879, 'category_id': 55, 'bbox': [470.7516174316406, 162.91452026367188, 29.08941650390625, 32.23643493652344], 'score': 0.05424657091498375}
# ✔ image_id exists
# ✔ category_id valid
# ✔ bbox format OK
# ✔ Overlaps GT (max IoU=0.087)
# ------------------------------------------------------------
#
# Prediction #38
# {'image_id': 231879, 'category_id': 57, 'bbox': [481.56256103515625, 168.83291625976562, 75.57781982421875, 28.846237182617188], 'score': 0.0535571463406086}
# ✔ image_id exists
# ✔ category_id valid
# ✔ bbox format OK
# ✔ Overlaps GT (max IoU=0.146)
# ------------------------------------------------------------
#
# Prediction #39
# {'image_id': 231879, 'category_id': 70, 'bbox': [473.68597412109375, 157.55189514160156, 61.02728271484375, 38.15019226074219], 'score': 0.05341019108891487}
# ✔ image_id exists
# ✔ category_id valid
# ✔ bbox format OK
# ✔ Overlaps GT (max IoU=0.216)
# ------------------------------------------------------------
#
# Prediction #40
# {'image_id': 231879, 'category_id': 25, 'bbox': [482.2261047363281, 159.08026123046875, 40.833221435546875, 34.80284118652344], 'score': 0.05235599726438522}
# ✔ image_id exists
# ✔ category_id valid
# ✔ bbox format OK
# ✔ Overlaps GT (max IoU=0.132)
# ------------------------------------------------------------
#
# Prediction #41
# {'image_id': 231879, 'category_id': 81, 'bbox': [493.41046142578125, 161.8651123046875, 54.557861328125, 41.71043395996094], 'score': 0.05079500004649162}
# ✔ image_id exists
# ✔ category_id valid
# ✔ bbox format OK
# ✔ Overlaps GT (max IoU=0.168)
# ------------------------------------------------------------
#
# Prediction #42
# {'image_id': 231879, 'category_id': 50, 'bbox': [458.7640380859375, 157.3150177001953, 69.62371826171875, 51.15533447265625], 'score': 0.05050045996904373}
# ✔ image_id exists
# ✔ category_id valid
# ✔ bbox format OK
# ✔ Overlaps GT (max IoU=0.286)
# ------------------------------------------------------------
#
# Prediction #43
# {'image_id': 27696, 'category_id': 15, 'bbox': [365.2633972167969, 2.1698079109191895, 57.475433349609375, 37.79214429855347], 'score': 0.10143620520830154}
# ✔ image_id exists
# ✔ category_id valid
# ✔ bbox format OK
# ✔ Overlaps GT (max IoU=0.655)
# ------------------------------------------------------------
#
# Prediction #44
# {'image_id': 27696, 'category_id': 55, 'bbox': [371.9912414550781, 1.2498430013656616, 43.556365966796875, 38.608009934425354], 'score': 0.05895671248435974}
# ✔ image_id exists
# ✔ category_id valid
# ✔ bbox format OK
# ✔ Overlaps GT (max IoU=0.609)
# ------------------------------------------------------------
#
# Prediction #45
# {'image_id': 27696, 'category_id': 17, 'bbox': [366.1983642578125, 0.6250376105308533, 55.828369140625, 47.79255348443985], 'score': 0.05777733400464058}
# ✔ image_id exists
# ✔ category_id valid
# ✔ bbox format OK
# ✔ Overlaps GT (max IoU=0.834)
# ------------------------------------------------------------
#
# Prediction #46
# {'image_id': 27696, 'category_id': 52, 'bbox': [366.8757629394531, 0.43732547760009766, 54.174285888671875, 45.39015865325928], 'score': 0.056488778442144394}
# ✔ image_id exists
# ✔ category_id valid
# ✔ bbox format OK
# ✔ Overlaps GT (max IoU=0.816)
# ------------------------------------------------------------
#
# Prediction #47
# {'image_id': 27696, 'category_id': 90, 'bbox': [374.48834228515625, 3.1382012367248535, 37.83880615234375, 42.64165639877319], 'score': 0.053886961191892624}
# ✔ image_id exists
# ✔ category_id valid
# ✔ bbox format OK
# ✔ Overlaps GT (max IoU=0.584)
# ------------------------------------------------------------
#
# Prediction #48
# {'image_id': 27696, 'category_id': 25, 'bbox': [371.0403747558594, 0.5490326285362244, 45.128021240234375, 40.91868358850479], 'score': 0.0524175651371479}
# ✔ image_id exists
# ✔ category_id valid
# ✔ bbox format OK
# ✔ Overlaps GT (max IoU=0.669)
# ------------------------------------------------------------
#
# Prediction #49
# {'image_id': 27696, 'category_id': 65, 'bbox': [371.0403747558594, 0.5490326285362244, 45.128021240234375, 40.91868358850479], 'score': 0.05233217775821686}
# ✔ image_id exists
# ✔ category_id valid
# ✔ bbox format OK
# ✔ Overlaps GT (max IoU=0.669)
# ------------------------------------------------------------
#
# Prediction #50
# {'image_id': 27696, 'category_id': 16, 'bbox': [365.2633972167969, 2.1698079109191895, 57.475433349609375, 37.79214429855347], 'score': 0.05133519694209099}
# ✔ image_id exists
# ✔ category_id valid
# ✔ bbox format OK
# ✔ Overlaps GT (max IoU=0.655)
# ------------------------------------------------------------
#
# 🎉 Sanity check passed for the first 50 predictions!

# %% [markdown]
# ## Put model on device & define inference helper

# %%
import torchvision.transforms as T
import numpy as np

device = "cuda" if torch.cuda.is_available() else "cpu"
model.to(device)

transform = T.Compose([
    T.ToTensor(),   # HWC uint8 RGB -> CHW float32 [0,1]
])

def run_efficientdet_on_image(img_bgr, score_thresh=0.05):
    """
    Runs EfficientDet on a single BGR image.

    - Resizes input to EfficientDet's expected size (INPUT_W, INPUT_H)
    - Runs model
    - Rescales boxes back to the original image size
    """
    if img_bgr is None:
        raise ValueError("img_bgr is None (cv2.imread failed)")

    # Original size
    orig_h, orig_w = img_bgr.shape[:2]

    # BGR -> RGB
    img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)

    # Resize to model input size
    img_resized = cv2.resize(img_rgb, (INPUT_W, INPUT_H))

    # To tensor
    tensor = transform(img_resized)          # [3, H_in, W_in]
    _, H_in, W_in = tensor.shape

    with torch.no_grad():
        batch = tensor.unsqueeze(0).to(device)   # [1, 3, H_in, W_in]
        preds = model(batch)

        # Most effdet versions: list[dict] with 'boxes', 'scores', 'labels'
        if isinstance(preds, (list, tuple)):
            p = preds[0]
            if isinstance(p, dict):
                boxes = p["boxes"].cpu().numpy()
                scores = p["scores"].cpu().numpy()
                labels = p["labels"].cpu().numpy()
            else:
                arr = p.cpu().numpy()
                boxes = arr[:, :4]
                scores = arr[:, 4]
                labels = arr[:, 5].astype(int)
        elif isinstance(preds, torch.Tensor):
            arr = preds[0].cpu().numpy()
            boxes = arr[:, :4]
            scores = arr[:, 4]
            labels = arr[:, 5].astype(int)
        else:
            raise RuntimeError(f"Unknown EfficientDet output type: {type(preds)}")

    # Filter by confidence
    keep = scores >= score_thresh
    boxes = boxes[keep]
    scores = scores[keep]
    labels = labels[keep]

    if len(boxes) == 0:
        return boxes, scores, labels

    # Boxes are in xyxy for the resized image -> scale back to original
    scale_x = orig_w / W_in
    scale_y = orig_h / H_in

    boxes[:, 0] *= scale_x   # x1
    boxes[:, 2] *= scale_x   # x2
    boxes[:, 1] *= scale_y   # y1
    boxes[:, 3] *= scale_y   # y2

    # Clip to original bounds
    boxes[:, 0] = np.clip(boxes[:, 0], 0, orig_w)
    boxes[:, 2] = np.clip(boxes[:, 2], 0, orig_w)
    boxes[:, 1] = np.clip(boxes[:, 1], 0, orig_h)
    boxes[:, 3] = np.clip(boxes[:, 3], 0, orig_h)

    return boxes, scores, labels

# %% [markdown]
# ## Loop through ALL validation images and save results to JSON file

# %%
import tqdm
import json
import numpy as np
from pycocotools.coco import COCO

# Load GT to build mappings
coco_gt = COCO(VAL_ANN)

img_id_map = {
    img["file_name"]: img["id"]
    for img in coco_gt.loadImgs(coco_gt.getImgIds())
}
cat_ids_sorted = sorted(coco_gt.getCatIds())

results = []

for img_name in tqdm.tqdm(image_files):
    img_path = os.path.join(VAL_IMAGES, img_name)
    img = cv2.imread(img_path)
    if img is None:
        continue

    boxes, scores, labels = run_efficientdet_on_image(img, score_thresh=0.001)

    image_id = img_id_map[img_name]

    for box, score, label in zip(boxes, scores, labels):
        x1, y1, x2, y2 = box.astype(float)
        w = x2 - x1
        h = y2 - y1

        label_idx = int(label)

        # Skip labels that don't map to any COCO category in this annotation file
        if label_idx < 0 or label_idx >= len(cat_ids_sorted):
            continue

        category_id = int(cat_ids_sorted[label_idx])

        results.append({
            "image_id": int(image_id),
            "category_id": category_id,
            "bbox": [float(x1), float(y1), float(w), float(h)],
            "score": float(score),
        })

output_path = "efficientdet_results.json"
with open(output_path, "w") as f:
    json.dump(results, f)

print("Saved result file to:", output_path)
print("Total predictions:", len(results))
# Out:
# loading annotations into memory...
# Done (t=0.13s)
# creating index...
# index created!
# 100%|█████████████████████████████████████████████████████████████| 3125/3125 [09:40<00:00,  5.38it/s]
# Saved result file to: efficientdet_results.json
# Total predictions: 5

# %% [markdown]
# ## Evaluation

# %%
from pycocotools.coco import COCO
from pycocotools.cocoeval import COCOeval
import numpy as np

# Load ground truth and EfficientDet detections
coco_gt = COCO(VAL_ANN)
coco_dt_eff = coco_gt.loadRes("efficientdet_results.json")

img_ids = sorted(coco_gt.getImgIds())

coco_eval_eff = COCOeval(coco_gt, coco_dt_eff, iouType="bbox")
coco_eval_eff.params.imgIds = img_ids

coco_eval_eff.evaluate()
coco_eval_eff.accumulate()
coco_eval_eff.summarize()   # prints standard COCO table

# ---- Extra metrics in the style of your screenshot ----
precision = coco_eval_eff.eval["precision"]  # [TxRxKxAxM]
recall    = coco_eval_eff.eval["recall"]     # [TxKxAxM]

# IoU = 0.50, area = all, maxDets = 100
prec_valid = precision[0, :, :, 0, 2]
prec_valid = prec_valid[prec_valid > -1]
prec_mean  = np.mean(prec_valid)

rec_valid = recall[0, :, 0, 2]
rec_valid = rec_valid[rec_valid > -1]
rec_mean  = np.mean(rec_valid)

f1 = 0 if (prec_mean + rec_mean) == 0 else 2 * (prec_mean * rec_mean) / (prec_mean + rec_mean)

print("\n### EfficientDet Model Accuracy Metrics\n")
print(f"mAP@50:95: {coco_eval_eff.stats[0]:.3f}")
print(f"mAP@50:   {coco_eval_eff.stats[1]:.3f}")
print(f"Precision (COCO-based): {prec_mean:.3f}")
print(f"Recall    (COCO-based): {rec_mean:.3f}")
print(f"F1-Score  (COCO-based): {f1:.3f}")
# Out:
# loading annotations into memory...
# Done (t=0.20s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=1.81s).
# Accumulating evaluation results...
# DONE (t=0.37s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#
# ### EfficientDet Model Accuracy Metrics
#
# mAP@50:95: 0.000
# mAP@50:   0.000
# Precision (COCO-based): 0.000
# Recall    (COCO-based): 0.000
# F1-Score  (COCO-based): 0.000
